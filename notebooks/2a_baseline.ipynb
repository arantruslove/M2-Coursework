# %%
import torch

from m2_utilities.load_data import load_trajectories
from m2_utilities.preprocessor import get_tokenizer, stringify, scale
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
trajectories = load_trajectories("data/lotka_volterra_data.h5")
scaled_trajectories, _ = scale(trajectories)
trajectory = scaled_trajectories[0]

# %%
tokenizer = get_tokenizer()
text = stringify(trajectory, decimals=2)
token_ids = tokenizer(text, return_tensors="pt", add_special_tokens=False)["input_ids"][0]


print(text)
print("")
print(token_ids.tolist())
# Out:
# 0.68,0.75;0.53,0.56;0.49,0.41;0.52,0.29;0.59,0.22;0.72,0.17;0.91,0.13;1.16,0.12;1.46,0.11;1.82,0.12;2.19,0.14;2.53,0.17;2.78,0.23;2.87,0.33;2.72,0.45;2.35,0.60;1.84,0.71;1.36,0.73;1.02,0.67;0.82,0.56;0.74,0.45;0.74,0.35;0.80,0.28;0.91,0.23;1.07,0.20;1.28,0.18;1.52,0.18;1.79,0.18;2.04,0.21;2.25,0.25;2.36,0.31;2.34,0.39;2.18,0.49;1.89,0.57;1.56,0.61;1.28,0.60;1.07,0.55;0.96,0.47;0.92,0.40;0.94,0.34;1.01,0.29;1.12,0.25;1.27,0.23;1.45,0.23;1.65,0.23;1.83,0.25;1.98,0.28;2.07,0.33;2.07,0.38;1.97,0.45;1.80,0.50;1.58,0.53;1.38,0.53;1.22,0.51;1.11,0.46;1.06,0.41;1.07,0.36;1.11,0.32;1.20,0.29;1.31,0.27;1.45,0.26;1.59,0.27;1.73,0.28;1.83,0.31;1.89,0.34;1.89,0.38;1.82,0.43;1.71,0.46;1.56,0.49;1.41,0.49;1.29,0.47;1.21,0.44;1.17,0.40;1.16,0.37;1.20,0.34;1.27,0.31;1.36,0.30;1.46,0.29;1.57,0.29;1.67,0.31;1.74,0.33;1.78,0.35;1.77,0.39;1.72,0.42;1.64,0.44;1.53,0.46;1.43,0.46;1.34,0.45;1.27,0.42;1.24,0.40;1.24,0.37;1.27,0.35;1.32,0.33;1.39,0.32;1.47,0.31;1.55,0.31;1.62,0.32;1.67,0.34;1.70,0.36;1.69,0.3
# ...
