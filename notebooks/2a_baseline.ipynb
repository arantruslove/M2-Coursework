# %%
import torch
import matplotlib.pyplot as plt
from transformers import AutoTokenizer

from m2_utilities.load_data import load_trajectories
from m2_utilities.preprocessor import stringify, tokenize

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
unscaled_trajectories = load_trajectories("data/lotka_volterra_data.h5")

ALPHA = 1.5
trajectories = unscaled_trajectories / ALPHA

# %%
stringified = stringify(trajectories, decimals=2)
all_tokens = tokenize(trajectories, decimals=2)

print(stringified[0])
print("")
print(all_tokens[0].tolist())
# Out:
# 0.63,0.69;0.49,0.52;0.45,0.38;0.48,0.27;0.55,0.20;0.67,0.15;0.84,0.12;1.07,0.11;1.35,0.10;1.68,0.11;2.03,0.12;2.35,0.16;2.58,0.21;2.65,0.30;2.52,0.42;2.17,0.55;1.70,0.65;1.26,0.68;0.94,0.62;0.76,0.52;0.69,0.41;0.69,0.33;0.74,0.26;0.84,0.21;0.99,0.18;1.18,0.17;1.41,0.16;1.65,0.17;1.89,0.19;2.08,0.23;2.19,0.29;2.17,0.36;2.01,0.45;1.75,0.53;1.45,0.56;1.18,0.56;0.99,0.51;0.89,0.44;0.85,0.37;0.87,0.31;0.93,0.27;1.04,0.23;1.18,0.22;1.35,0.21;1.52,0.21;1.70,0.23;1.84,0.26;1.92,0.30;1.91,0.36;1.83,0.41;1.66,0.46;1.47,0.49;1.28,0.49;1.12,0.47;1.03,0.43;0.98,0.38;0.99,0.33;1.03,0.29;1.11,0.27;1.22,0.25;1.34,0.24;1.47,0.25;1.60,0.26;1.70,0.28;1.75,0.32;1.75,0.36;1.69,0.40;1.58,0.43;1.44,0.45;1.31,0.45;1.20,0.44;1.12,0.41;1.08,0.37;1.08,0.34;1.11,0.31;1.17,0.29;1.25,0.27;1.35,0.27;1.45,0.27;1.54,0.28;1.61,0.30;1.65,0.33;1.64,0.36;1.59,0.39;1.52,0.41;1.42,0.42;1.32,0.42;1.24,0.41;1.18,0.39;1.15,0.37;1.15,0.34;1.17,0.32;1.22,0.30;1.29,0.29;1.36,0.29;1.43,0.29;1.50,0.30;1.55,0.32;1.57,0.34;1.56,0.3
# ...
